# %%
import requests
import re
import time
import bs4

# %%
ncbs_url = 'https://www.azlyrics.com/n/nickcavethebadseeds.html'

# %%
ncbs_html = requests.get(ncbs_url).text

# %%
#ncbs_html

# %%
ncbs_soup = bs4.BeautifulSoup(ncbs_html, "html")

# %%
ncbs_soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
# <meta content='Nick Cave &amp; The Bad Seeds lyrics - 206 song lyrics sorted by album, including "Red Right Hand", "Into My Arms", "O Children".' name="description"/>
# <meta content="Nick Cave &amp; The Bad Seeds, Nick Cave &amp; The Bad Seeds lyrics, discography, albums, songs" name="keywords"/>
# <meta content="noarchive" name="robots"/>
# <title>Nick Cave &amp; The Bad Seeds Lyrics</title>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/local/az.css" rel="stylesheet"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
# ...

# %%
results = re.findall('{s:', ncbs_soup.text)
href="../lyrics(.+?)

# %%
results
# Out:
# []

# %%
ncbs_soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
# <meta content='Nick Cave &amp; The Bad Seeds lyrics - 206 song lyrics sorted by album, including "Red Right Hand", "Into My Arms", "O Children".' name="description"/>
# <meta content="Nick Cave &amp; The Bad Seeds, Nick Cave &amp; The Bad Seeds lyrics, discography, albums, songs" name="keywords"/>
# <meta content="noarchive" name="robots"/>
# <title>Nick Cave &amp; The Bad Seeds Lyrics</title>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/local/az.css" rel="stylesheet"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
# ...
